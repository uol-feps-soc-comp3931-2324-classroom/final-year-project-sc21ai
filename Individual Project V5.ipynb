# %%
import pandas as pd #For reading csv files.
import numpy as np 
import matplotlib.pyplot as plt #For plotting.
import matplotlib.colors as mcolors
import os

import PIL.Image as Image #For working with image files.

#Importing torch
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset,DataLoader #For working with data.

from torchvision import models,transforms #For pretrained models,image transformations.

torch.cuda.empty_cache()

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu') #Use GPU if it's available or else use CPU.
print(device) #Prints the device we're using.
# Out:
# cuda

# %%
path = "aptos2019-blindness-detection/"

train_df = pd.read_csv(f"{path}train.csv")
print(f'No.of.training_samples: {len(train_df)}')

test_df = pd.read_csv(f'{path}test.csv')
print(f'No.of.testing_samples: {len(test_df)}')
# Out:
# No.of.training_samples: 3662
# No.of.testing_samples: 1928

# %% [raw]
# def check_image_load(image_path):
#     try:
#         # Attempt to open the image
#         Image.open(image_path).convert('RGB')
#         return True  # Image successfully loaded
#     except:
#         return False  # Image failed to load
#
# # For train_df
# train_df['image_loaded'] = train_df['id_code'].apply(lambda x: check_image_load(f"{path}train_images/{x}.png"))
#
# # Filter out images that failed to load
# train_df_filtered = train_df[train_df['image_loaded']]
#
# print(f'No.of.training_samples after excluding failed images: {len(train_df_filtered)}')
#
# # For test_df
# test_df['image_loaded'] = test_df['id_code'].apply(lambda x: check_image_load(f"{path}test_images/{x}.png"))
#
# # Filter out images that failed to load
# test_df_filtered = test_df[test_df['image_loaded']]
#
# print(f'No.of.testing_samples after excluding failed images: {len(test_df_filtered)}')

# %%
bins = np.arange(-0.5, max(train_df.diagnosis) + 1.5, 1)

# Plot histogram with adjusted bins
plt.hist(train_df.diagnosis, bins=bins, rwidth=0.8, align='mid')

# Set x-ticks to be at the center of each bar
plt.xticks(np.arange(0, 5, 1))

# Turn off the grid or adjust it
plt.grid(False)

# Show the plot
plt.show()

# %%
#As you can see,the data is imbalanced.
#So we've to calculate weights for each class,which can be used in calculating loss.

from sklearn.utils import class_weight #For calculating weights for each class.
class_weights = class_weight.compute_class_weight(class_weight='balanced',classes=np.array([0,1,2,3,4]),y=train_df['diagnosis'].values)
class_weights = torch.tensor(class_weights,dtype=torch.float).to(device)
 
print(class_weights) #Prints the calculated weights for the classes.
# Out:
# tensor([0.4058, 1.9795, 0.7331, 3.7948, 2.4827], device='cuda:0')

# %%
# Set the number of images to display
num_images = 20

# Generate a list of random indices based on the DataFrame length
random_indices = np.random.randint(0, len(train_df), size=num_images)

# Set up the plot - adjust subplot grid as needed
fig, axes = plt.subplots(nrows=4, ncols=5, figsize=(20, 16)) # Adjust nrows and ncols based on num_images
axes = axes.flatten()

for i, ax in zip(random_indices, axes):
    # Construct the full path to the image
    sample_image_path = f'{path}train_images/{train_df["id_code"][i]}.png'
    sample_image = Image.open(sample_image_path)
    
    # Plotting
    ax.imshow(sample_image)
    ax.axis('off') # Hides the axis
    ax.set_title(f'Class: {train_df["diagnosis"][i]}') # Shows the class of each image

# Adjusts subplot params so that the subplot(s) fits in to the figure area
plt.tight_layout()
plt.show()

# %%
class CustomCropAndResize:
    def __call__(self, img):
        # Convert image to grayscale for thresholding
        gray = img.convert('L')
        img_array = np.array(gray)

        # Create a binary mask where non-black pixels are set to 255 (non-transparent)
        threshold = 10
        mask = np.where(img_array > threshold, 255, 0).astype(np.uint8)

        # Convert the numpy array mask to a PIL Image
        mask_image = Image.fromarray(mask, mode='L')

        # Apply this mask to the original image to make the background transparent
        img.putalpha(mask_image)

        return img

# %%
class dataset(Dataset): # Inherits from the Dataset class.
    '''
    dataset class overloads the __init__, __len__, __getitem__ methods of the Dataset class. 
    
    Attributes :
        df:  DataFrame object for the csv file.
        data_path: Location of the dataset.
        image_transform: Transformations to apply to the image.
        train: A boolean indicating whether it is a training_set or not.
    '''
    
    def __init__(self,df,data_path,image_transform=None,train=True): # Constructor.
        super(Dataset,self).__init__() #Calls the constructor of the Dataset class.
        self.df = df
        self.data_path = data_path
        self.image_transform = image_transform
        self.train = train
        
    def __len__(self):
        return len(self.df) #Returns the number of samples in the dataset.
    
    def __getitem__(self,index):
        image_id = self.df['id_code'][index]
        image = Image.open(f'{self.data_path}/{image_id}.png') #Image.
        if self.image_transform :
            image = self.image_transform(image) #Applies transformation to the image.
        
        if self.train :
            label = self.df['diagnosis'][index] #Label.
            return image,label #If train == True, return image & label.
        
        else:
            return image #If train != True, return image.

# %%
class DoubleConv(nn.Module):
    """(convolution => [BN] => ReLU) * 2"""
    def __init__(self, in_channels, out_channels, mid_channels=None):
        super().__init__()
        if not mid_channels:
            mid_channels = out_channels
        self.double_conv = nn.Sequential(
            nn.Conv2d(in_channels, mid_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(mid_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(mid_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        return self.double_conv(x)

# %%
class ConvBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(ConvBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1)
        self.relu = nn.ReLU(inplace=True)
        self.dropout = nn.Dropout2d(0.5)  # Spatial dropout
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1)

    def forward(self, x):
        x = self.conv1(x)
        x = self.relu(x)
        x = self.conv2(x)
        x = self.relu(x)
        return x

# %%
class AttentionGate(nn.Module):
    def __init__(self, F_g, F_l, F_int):
        super(AttentionGate, self).__init__()
        self.W_g = nn.Sequential(
            nn.Conv2d(F_g, F_int, kernel_size=1, stride=1, padding=0, bias=True),
            nn.BatchNorm2d(F_int)
        )
        
        self.W_x = nn.Sequential(
            nn.Conv2d(F_l, F_int, kernel_size=1, stride=1, padding=0, bias=True),
            nn.BatchNorm2d(F_int)
        )

        self.psi = nn.Sequential(
            nn.Conv2d(F_int, 1, kernel_size=1, stride=1, padding=0, bias=True),
            nn.BatchNorm2d(1),
            nn.Sigmoid()
        )
        
        self.relu = nn.ReLU(inplace=True)

    def forward(self, g, x):
        g1 = self.W_g(g)
        x1 = self.W_x(x)
        psi = self.relu(g1 + x1)
        psi = self.psi(psi)
        return x * psi

# %%
class UpConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(UpConv, self).__init__()
        self.up = nn.Sequential(
            nn.Upsample(scale_factor=2),
            nn.Conv2d(in_channels, out_channels, kernel_size=1)
        )

    def forward(self, x):
        return self.up(x)

# %%
class AttentionUNet(nn.Module):
    def __init__(self, in_channels=4, out_channels=5):
        super(AttentionUNet, self).__init__()
        # Reducing the number of filters in each convolutional block
        self.inc = DoubleConv(in_channels, 32)  # Reduced from 64 to 32
        self.down1 = DoubleConv(32, 64)  # Reduced from 128 to 64
        self.down2 = DoubleConv(64, 128)  # Reduced from 256 to 128
        self.down3 = DoubleConv(128, 256)  # Reduced from 512 to 256

        self.up1 = UpConv(256, 128)
        self.att1 = AttentionGate(128, 128, 64)  # Simplified attention gate
        self.up_conv1 = DoubleConv(256, 128)

        self.up2 = UpConv(128, 64)
        self.att2 = AttentionGate(64, 64, 32)
        self.up_conv2 = DoubleConv(128, 64)

        self.up3 = UpConv(64, 32)
        self.att3 = AttentionGate(32, 32, 16)
        self.up_conv3 = DoubleConv(64, 32)

        self.outc = nn.Conv2d(32, out_channels, kernel_size=1)
        
        self.global_avg_pool = nn.AdaptiveAvgPool2d((1, 1))
        self.classifier = nn.Linear(32, out_channels)  # Reduced width

    def forward(self, x):
        x1 = self.inc(x)
        x2 = F.max_pool2d(self.down1(x1), 2)
        x3 = F.max_pool2d(self.down2(x2), 2)
        x4 = F.max_pool2d(self.down3(x3), 2)

        x = self.up1(x4)
        g1 = self.att1(x, x3)
        x = self.up_conv1(torch.cat([x, g1], dim=1))

        x = self.up2(x)
        g2 = self.att2(x, x2)
        x = self.up_conv2(torch.cat([x, g2], dim=1))

        x = self.up3(x)
        g3 = self.att3(x, x1)
        x = self.up_conv3(torch.cat([x, g3], dim=1))

        x = self.global_avg_pool(x)
        x = x.view(x.size(0), -1)
        logits = self.classifier(x)
        return logits

# %%
class EarlyStopping:
    """Early stops the training if validation loss doesn't improve after a given patience."""
    def __init__(self, patience=7, verbose=False, delta=0):
        """
        Args:
            patience (int): How long to wait after last time validation loss improved.
                            Default: 7
            verbose (bool): If True, prints a message for each validation loss improvement. 
                            Default: False
            delta (float): Minimum change in the monitored quantity to qualify as an improvement.
                            Default: 0
        """
        self.patience = patience
        self.verbose = verbose
        self.delta = delta
        self.best_score = None
        self.early_stop = False
        self.counter = 0

    def __call__(self, val_loss, model):
        score = -val_loss

        if self.best_score is None:
            self.best_score = score
        elif score < self.best_score + self.delta:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.counter = 0

# %%
image_transform = transforms.Compose([CustomCropAndResize(),
                                      transforms.Resize([256, 256]),
                                      transforms.ToTensor(),
                                      transforms.Normalize((0.485, 0.456, 0.406, 0), (0.229, 0.224, 0.225, 1))]) #Transformations to apply to the image.
data_set = dataset(train_df,f'{path}train_images',image_transform=image_transform)

#Split the data_set so that valid_set contains 0.1 samples of the data_set. 
train_size = int(0.9 * len(data_set))
valid_size = len(data_set) - train_size

train_set, valid_set = torch.utils.data.random_split(data_set, [train_size, valid_size])

# %%
train_dataloader = DataLoader(train_set,batch_size=16,shuffle=True, num_workers=4) #DataLoader for train_set.
valid_dataloader = DataLoader(valid_set,batch_size=16,shuffle=False, num_workers=4) #DataLoader for validation_set.

# %%
model = AttentionUNet() 
model = model.to(device) #Moves the model to the device.

# %%
def generate_saliency_maps(model, dataloader, epoch, device, save_dir, num_images=20):
    model.eval()
    epoch_dir = os.path.join(save_dir, f'Epoch_{epoch+1}')
    os.makedirs(epoch_dir, exist_ok=True)

    total_images_processed = 0
    images_processed = 0

    # Create a custom thermal-like colormap from blue to red
    colors = [(0, 0, 1, 1)] + [(x, 0, 1-x, 1) for x in np.linspace(0, 1, 128)] + [(1, x, 0, 1) for x in np.linspace(0, 1, 127)]
    cmap = mcolors.LinearSegmentedColormap.from_list('custom_thermal', colors, N=256)

    # Iterate over all batches
    for batch_idx, (images, labels) in enumerate(dataloader):
        images = images.to(device)

        for idx in range(images.size(0)):
            if images_processed < num_images:
                image = images[idx].unsqueeze(0)
                image.requires_grad = True

                # Forward pass
                outputs = model(image)
                score, predicted = torch.max(outputs, 1)

                # Backward pass
                model.zero_grad()
                score.backward()

                # Saliency map computation
                saliency = image.grad.data.abs().squeeze()
                saliency = saliency.sum(dim=0)  # Sum across the color channels to get a 2D saliency map
                saliency = saliency / saliency.max()  # Normalize

                # Normalize the original image for display
                original_img = image.cpu().detach().numpy().squeeze().transpose(1, 2, 0)
                original_img = (original_img - original_img.min()) / (original_img.max() - original_img.min())

                # Plotting
                fig, ax = plt.subplots(1, 2, figsize=(12, 6))
                # Original image
                ax[0].imshow(original_img)
                ax[0].set_title('Original Image')
                ax[0].axis('off')

                # Saliency map
                ax[1].imshow(saliency.cpu(), cmap=cmap)
                ax[1].set_title('Saliency Map')
                ax[1].axis('off')

                plt.suptitle(f'Actual: {labels[idx].item()}, Predicted: {predicted.item()}')
                plt.savefig(os.path.join(epoch_dir, f'Saliency_{total_images_processed}.png'))
                plt.close()

                images_processed += 1
            total_images_processed += 1

            if images_processed >= num_images:
                break
        if images_processed >= num_images:
            break

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-5)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=5, verbose=True)
early_stopping = EarlyStopping(patience=10, verbose=True)


# Compute class weights and convert to tensor
class_weights = torch.tensor(class_weight.compute_class_weight(class_weight='balanced', classes=np.unique(train_df['diagnosis']), y=train_df['diagnosis'].values), dtype=torch.float).to(device)
criterion = nn.CrossEntropyLoss(weight=class_weights)

num_epochs = 100
train_losses = []  # Store training losses
valid_losses = []  # Store validation losses
train_accuracies = []  # Store training accuracy
valid_accuracies = []  # Store validation accuracy

for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    train_correct = 0
    train_total = 0
    print(f'Epoch {epoch+1}/{num_epochs}')
    print('-------------------------------')
    
    for images, labels in train_dataloader:
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        train_total += labels.size(0)
        train_correct += (predicted == labels).sum().item()

    train_loss = running_loss / len(train_dataloader)
    train_accuracy = 100 * train_correct / train_total
    train_losses.append(train_loss)
    train_accuracies.append(train_accuracy)

    # Validation phase
    model.eval()
    running_loss = 0.0
    valid_correct = 0
    valid_total = 0
    with torch.no_grad():
        for images, labels in valid_dataloader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            running_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            valid_total += labels.size(0)
            valid_correct += (predicted == labels).sum().item()

    validation_loss = running_loss / len(valid_dataloader)
    validation_accuracy = 100 * valid_correct / valid_total
    valid_losses.append(validation_loss)
    valid_accuracies.append(validation_accuracy)

    scheduler.step(validation_loss)

    print(f'Training Loss = {train_loss:.6f}, Accuracy = {train_accuracy:.2f}%')
    print(f'Validation Loss = {validation_loss:.6f}, Accuracy = {validation_accuracy:.2f}%')
    
    generate_saliency_maps(model, valid_dataloader, epoch, device, 'v5_combo_saliency_maps')
    
    if early_stopping(validation_loss, model):
        print("Early stopping triggered.")
        break

    print(f'Epoch {epoch+1} completed. Saliency maps generated.')
    torch.cuda.empty_cache()
# Out:
# Epoch 1/100
# -------------------------------
# Training Loss = 1.477010, Accuracy = 51.23%
# Validation Loss = 1.397022, Accuracy = 57.49%
# Epoch 1 completed. Saliency maps generated.
# Epoch 2/100
# -------------------------------
# Training Loss = 1.353102, Accuracy = 61.12%
# Validation Loss = 1.293092, Accuracy = 62.40%
# Epoch 2 completed. Saliency maps generated.
# Epoch 3/100
# -------------------------------
# Training Loss = 1.295428, Accuracy = 63.76%
# Validation Loss = 1.236220, Accuracy = 70.57%
# Epoch 3 completed. Saliency maps generated.
# Epoch 4/100
# -------------------------------
# Training Loss = 1.269871, Accuracy = 64.76%
# Validation Loss = 1.241590, Accuracy = 63.76%
# Epoch 4 completed. Saliency maps generated.
# Epoch 5/100
# -------------------------------
# Training Loss = 1.250503, Accuracy = 65.16%
# Validation Loss = 1.320512, Accuracy = 64.58%
# Epoch 5 completed. Saliency maps generated.
# Epoch 6/100
# -------------------------------
# Training Loss = 1.224312, Accuracy = 64.67%
# Validation Loss = 1.449475, Accuracy = 51.23%
# Epoch 6 completed. Saliency maps generated.
# Epoch 7/100
# -------------------------------
# Training Loss = 1.215015, Accuracy = 63.95%
# Validation Loss = 1.189677, Accuracy = 61.04%
# Epoch 7 completed. Saliency maps generated.
# Epoch 8/100
# -------------------------------
# Training Loss = 1.163692, Accuracy = 65.22%
# Validation Loss = 1.374207, Accuracy = 58.31%
# Epoch 8 completed. Saliency maps generated.
# Epoch 9/100
# -------------------------------
# Training Loss = 1.126770, Accuracy = 67.04%
# Validation Loss = 1.423852, Accuracy = 54.22%
# Epoch 9 completed. Saliency maps generated.
# Epoch 10/100
# -------------------------------
# Training Loss = 1.112059, Accuracy = 66.74%
# Validation Loss = 1.400606, Accuracy = 60.76%
# Epoch 10 completed. Saliency maps generated.
# Epoch 11/100
# -------------------------------
# Training Loss = 1.097046, Accuracy = 67.07%
# Validation Loss = 1.022827, Accuracy = 64.31%
# Epoch 11 completed. Saliency maps generated.
# Epoch 12/100
# -------------------------------
# Training Loss = 1.048693, Accuracy = 69.17%
# Validation Loss = 1.119750, Accuracy = 64.03%
# Epoch 12 completed. Saliency maps generated.
# Epoch 13/100
# -------------------------------
# Training Loss = 1.013634, Accuracy = 68.92%
# Validation Loss = 1.057038, Accuracy = 66.49%
# Epoch 13 completed. Saliency maps generated.
# Epoch 14/100
# -------------------------------
# Training Loss = 0.991624, Accuracy = 71.35%
# Validation Loss = 1.001004, Accuracy = 73.84%
# Epoch 14 completed. Saliency maps generated.
# Epoch 15/100
# -------------------------------
# Training Loss = 0.993026, Accuracy = 70.96%
# Validation Loss = 0.940668, Accuracy = 75.20%
# Epoch 15 completed. Saliency maps generated.
# Epoch 16/100
# -------------------------------
# Training Loss = 0.974677, Accuracy = 70.83%
# Validation Loss = 0.953457, Accuracy = 72.75%
# Epoch 16 completed. Saliency maps generated.
# Epoch 17/100
# -------------------------------
# Training Loss = 0.934389, Accuracy = 73.41%
# Validation Loss = 0.959181, Accuracy = 68.39%
# Epoch 17 completed. Saliency maps generated.
# Epoch 18/100
# -------------------------------
# Training Loss = 0.922496, Accuracy = 72.53%
# Validation Loss = 0.926591, Accuracy = 70.03%
# Epoch 18 completed. Saliency maps generated.
# Epoch 19/100
# -------------------------------
# Training Loss = 0.916374, Accuracy = 73.14%
# Validation Loss = 0.893653, Accuracy = 75.20%
# Epoch 19 completed. Saliency maps generated.
# Epoch 20/100
# -------------------------------
# Training Loss = 0.899271, Accuracy = 74.20%
# Validation Loss = 1.072699, Accuracy = 73.84%
# Epoch 20 completed. Saliency maps generated.
# Epoch 21/100
# -------------------------------
# Training Loss = 0.886957, Accuracy = 74.84%
# Validation Loss = 0.925433, Accuracy = 72.48%
# Epoch 21 completed. Saliency maps generated.
# Epoch 22/100
# -------------------------------
# Training Loss = 0.858775, Accuracy = 75.42%
# Validation Loss = 0.872064, Accuracy = 72.75%
# Epoch 22 completed. Saliency maps generated.
# Epoch 23/100
# -------------------------------
# Training Loss = 0.875436, Accuracy = 75.11%
# Validation Loss = 1.063795, Accuracy = 65.94%
# Epoch 23 completed. Saliency maps generated.
# Epoch 24/100
# -------------------------------
# Training Loss = 0.871961, Accuracy = 75.02%
# Validation Loss = 0.965475, Accuracy = 67.03%
# Epoch 24 completed. Saliency maps generated.
# Epoch 25/100
# -------------------------------
# Training Loss = 0.859601, Accuracy = 75.84%
# Validation Loss = 0.940016, Accuracy = 72.21%
# Epoch 25 completed. Saliency maps generated.
# Epoch 26/100
# -------------------------------
# Training Loss = 0.825482, Accuracy = 76.60%
# Validation Loss = 0.836431, Accuracy = 76.84%
# Epoch 26 completed. Saliency maps generated.
# Epoch 27/100
# -------------------------------
# Training Loss = 0.813601, Accuracy = 77.45%
# Validation Loss = 0.831258, Accuracy = 74.93%
# Epoch 27 completed. Saliency maps generated.
# Epoch 28/100
# -------------------------------
# Training Loss = 0.814783, Accuracy = 76.81%
# Validation Loss = 0.891548, Accuracy = 72.21%
# Epoch 28 completed. Saliency maps generated.
# Epoch 29/100
# -------------------------------
# Training Loss = 0.781586, Accuracy = 77.06%
# Validation Loss = 0.909684, Accuracy = 77.66%
# Epoch 29 completed. Saliency maps generated.
# Epoch 30/100
# -------------------------------
# Training Loss = 0.769751, Accuracy = 78.27%
# Validation Loss = 0.878115, Accuracy = 74.39%
# Epoch 30 completed. Saliency maps generated.
# Epoch 31/100
# -------------------------------
# Training Loss = 0.757037, Accuracy = 78.18%
# Validation Loss = 1.347414, Accuracy = 57.49%
# Epoch 31 completed. Saliency maps generated.
# Epoch 32/100
# -------------------------------
# Training Loss = 0.729714, Accuracy = 78.69%
# Validation Loss = 0.878253, Accuracy = 78.47%
# Epoch 32 completed. Saliency maps generated.
# Epoch 33/100
# -------------------------------
# Epoch 00033: reducing learning rate of group 0 to 1.0000e-04.
# Training Loss = 0.714565, Accuracy = 79.76%
# Validation Loss = 1.269552, Accuracy = 67.30%
# Epoch 33 completed. Saliency maps generated.
# Epoch 34/100
# -------------------------------
# Training Loss = 0.615919, Accuracy = 83.43%
# Validation Loss = 0.831005, Accuracy = 77.66%
# Epoch 34 completed. Saliency maps generated.
# Epoch 35/100
# -------------------------------
# Training Loss = 0.568056, Accuracy = 85.07%
# Validation Loss = 0.826030, Accuracy = 78.20%
# Epoch 35 completed. Saliency maps generated.
# Epoch 36/100
# -------------------------------
# Training Loss = 0.557237, Accuracy = 85.80%
# Validation Loss = 0.825299, Accuracy = 79.56%
# Epoch 36 completed. Saliency maps generated.
# Epoch 37/100
# -------------------------------
# Training Loss = 0.552369, Accuracy = 86.56%
# Validation Loss = 0.862417, Accuracy = 78.20%
# Epoch 37 completed. Saliency maps generated.
# Epoch 38/100
# -------------------------------
# Training Loss = 0.524774, Accuracy = 87.34%
# Validation Loss = 0.811382, Accuracy = 78.75%
# Epoch 38 completed. Saliency maps generated.
# Epoch 39/100
# -------------------------------
# Training Loss = 0.510937, Accuracy = 87.83%
# Validation Loss = 0.811311, Accuracy = 80.38%
# Epoch 39 completed. Saliency maps generated.
# Epoch 40/100
# -------------------------------
# Training Loss = 0.488522, Accuracy = 89.04%
# Validation Loss = 0.813136, Accuracy = 78.47%
# Epoch 40 completed. Saliency maps generated.
# Epoch 41/100
# -------------------------------
# Training Loss = 0.485128, Accuracy = 88.71%
# Validation Loss = 0.834780, Accuracy = 78.47%
# Epoch 41 completed. Saliency maps generated.
# Epoch 42/100
# -------------------------------
# Training Loss = 0.469226, Accuracy = 89.44%
# Validation Loss = 0.813905, Accuracy = 80.65%
# Epoch 42 completed. Saliency maps generated.
# Epoch 43/100
# -------------------------------
# Training Loss = 0.463495, Accuracy = 89.68%
# Validation Loss = 0.824970, Accuracy = 80.11%
# Epoch 43 completed. Saliency maps generated.
# Epoch 44/100
# -------------------------------
# Epoch 00044: reducing learning rate of group 0 to 1.0000e-05.
# Training Loss = 0.448235, Accuracy = 90.38%
# Validation Loss = 0.815026, Accuracy = 81.20%
# Epoch 44 completed. Saliency maps generated.
# Epoch 45/100
# -------------------------------
# Training Loss = 0.431301, Accuracy = 90.74%
# Validation Loss = 0.833676, Accuracy = 79.84%
# Epoch 45 completed. Saliency maps generated.
# Epoch 46/100
# -------------------------------
# Training Loss = 0.414718, Accuracy = 91.50%
# Validation Loss = 0.829789, Accuracy = 79.29%
# Epoch 46 completed. Saliency maps generated.
# Epoch 47/100
# -------------------------------
# Training Loss = 0.425378, Accuracy = 91.41%
# Validation Loss = 0.831803, Accuracy = 80.38%
# Epoch 47 completed. Saliency maps generated.
# Epoch 48/100
# -------------------------------
# Training Loss = 0.421080, Accuracy = 90.80%
# Validation Loss = 0.848509, Accuracy = 79.29%
# Epoch 48 completed. Saliency maps generated.
# Epoch 49/100
# -------------------------------
# Training Loss = 0.422980, Accuracy = 91.20%
# Validation Loss = 0.823019, Accuracy = 80.65%
# Epoch 49 completed. Saliency maps generated.
# Epoch 50/100
# -------------------------------
# Epoch 00050: reducing learning rate of group 0 to 1.0000e-06.
# Training Loss = 0.428549, Accuracy = 90.80%
# Validation Loss = 0.833795, Accuracy = 79.84%
# Epoch 50 completed. Saliency maps generated.
# Epoch 51/100
# -------------------------------
# Training Loss = 0.423223, Accuracy = 91.41%
# Validation Loss = 0.831858, Accuracy = 80.38%
# Epoch 51 completed. Saliency maps generated.
# Epoch 52/100
# -------------------------------
# Training Loss = 0.408441, Accuracy = 92.23%
# Validation Loss = 0.827378, Accuracy = 80.38%
# Epoch 52 completed. Saliency maps generated.
# Epoch 53/100
# -------------------------------
# Training Loss = 0.414316, Accuracy = 91.81%
# Validation Loss = 0.822464, Accuracy = 79.84%
# Epoch 53 completed. Saliency maps generated.
# Epoch 54/100
# -------------------------------
# Training Loss = 0.403545, Accuracy = 92.02%
# Validation Loss = 0.840111, Accuracy = 79.29%
# Epoch 54 completed. Saliency maps generated.
# Epoch 55/100
# -------------------------------
# Training Loss = 0.413394, Accuracy = 92.11%
# Validation Loss = 0.828283, Accuracy = 79.84%
# Epoch 55 completed. Saliency maps generated.
# Epoch 56/100
# -------------------------------
# Epoch 00056: reducing learning rate of group 0 to 1.0000e-07.
# Training Loss = 0.410421, Accuracy = 91.96%
# Validation Loss = 0.831081, Accuracy = 81.47%
# Epoch 56 completed. Saliency maps generated.
# Epoch 57/100
# -------------------------------
# Training Loss = 0.410035, Accuracy = 92.20%
# Validation Loss = 0.836015, Accuracy = 79.29%
# Epoch 57 completed. Saliency maps generated.
# Epoch 58/100
# -------------------------------
# Training Loss = 0.419909, Accuracy = 91.35%
# Validation Loss = 0.838975, Accuracy = 80.38%
# Epoch 58 completed. Saliency maps generated.
# Epoch 59/100
# -------------------------------
# Training Loss = 0.415728, Accuracy = 91.84%
# Validation Loss = 0.841418, Accuracy = 79.84%
# Epoch 59 completed. Saliency maps generated.
# Epoch 60/100
# -------------------------------
# Training Loss = 0.409770, Accuracy = 92.02%
# Validation Loss = 0.840557, Accuracy = 79.56%
# Epoch 60 completed. Saliency maps generated.
# Epoch 61/100
# -------------------------------
# Training Loss = 0.420892, Accuracy = 91.08%
# Validation Loss = 0.832595, Accuracy = 79.56%
# Epoch 61 completed. Saliency maps generated.
# Epoch 62/100
# -------------------------------
# Epoch 00062: reducing learning rate of group 0 to 1.0000e-08.
# Training Loss = 0.420392, Accuracy = 91.26%
# Validation Loss = 0.824295, Accuracy = 79.84%
# Epoch 62 completed. Saliency maps generated.
# Epoch 63/100
# -------------------------------
# Training Loss = 0.413277, Accuracy = 91.65%
# Validation Loss = 0.837033, Accuracy = 80.38%
# Epoch 63 completed. Saliency maps generated.
# Epoch 64/100
# -------------------------------
# Training Loss = 0.425212, Accuracy = 90.77%
# Validation Loss = 0.833563, Accuracy = 80.11%
# Epoch 64 completed. Saliency maps generated.
# Epoch 65/100
# -------------------------------
# Training Loss = 0.412657, Accuracy = 91.65%
# Validation Loss = 0.850370, Accuracy = 79.02%
# Epoch 65 completed. Saliency maps generated.
# Epoch 66/100
# -------------------------------
# Training Loss = 0.413453, Accuracy = 91.44%
# Validation Loss = 0.834395, Accuracy = 80.11%
# Epoch 66 completed. Saliency maps generated.
# Epoch 67/100
# -------------------------------
# Training Loss = 0.413022, Accuracy = 91.93%
# Validation Loss = 0.848721, Accuracy = 79.02%
# Epoch 67 completed. Saliency maps generated.
# Epoch 68/100
# -------------------------------
# Training Loss = 0.408712, Accuracy = 91.90%
# Validation Loss = 0.834799, Accuracy = 80.65%
# Epoch 68 completed. Saliency maps generated.
# Epoch 69/100
# -------------------------------
# Training Loss = 0.414539, Accuracy = 91.17%
# Validation Loss = 0.819855, Accuracy = 80.65%
# Epoch 69 completed. Saliency maps generated.
# Epoch 70/100
# -------------------------------
# Training Loss = 0.414096, Accuracy = 91.56%
# Validation Loss = 0.844318, Accuracy = 79.84%
# Epoch 70 completed. Saliency maps generated.
# Epoch 71/100
# -------------------------------
# Training Loss = 0.420123, Accuracy = 91.56%
# Validation Loss = 0.846532, Accuracy = 78.47%
# Epoch 71 completed. Saliency maps generated.
# Epoch 72/100
# -------------------------------
# Training Loss = 0.415210, Accuracy = 91.23%
# Validation Loss = 0.821516, Accuracy = 80.38%
# Epoch 72 completed. Saliency maps generated.
# Epoch 73/100
# -------------------------------
# Training Loss = 0.413067, Accuracy = 91.56%
# Validation Loss = 0.825112, Accuracy = 80.11%
# Epoch 73 completed. Saliency maps generated.
# Epoch 74/100
# -------------------------------
# Training Loss = 0.418500, Accuracy = 91.02%
# Validation Loss = 0.835813, Accuracy = 80.11%
# Epoch 74 completed. Saliency maps generated.
# Epoch 75/100
# -------------------------------
# Training Loss = 0.412444, Accuracy = 91.53%
# Validation Loss = 0.817330, Accuracy = 80.93%
# Epoch 75 completed. Saliency maps generated.
# Epoch 76/100
# -------------------------------
# Training Loss = 0.420913, Accuracy = 91.59%
# Validation Loss = 0.820991, Accuracy = 80.38%
# Epoch 76 completed. Saliency maps generated.
# Epoch 77/100
# -------------------------------
# Training Loss = 0.416645, Accuracy = 91.41%
# Validation Loss = 0.827256, Accuracy = 79.84%
# Epoch 77 completed. Saliency maps generated.
# Epoch 78/100
# -------------------------------
# Training Loss = 0.411943, Accuracy = 92.02%
# Validation Loss = 0.828586, Accuracy = 80.65%
# Epoch 78 completed. Saliency maps generated.
# Epoch 79/100
# -------------------------------
# Training Loss = 0.413638, Accuracy = 91.68%
# Validation Loss = 0.822315, Accuracy = 80.38%
# Epoch 79 completed. Saliency maps generated.
# Epoch 80/100
# -------------------------------
# Training Loss = 0.409151, Accuracy = 91.78%
# Validation Loss = 0.828830, Accuracy = 80.11%
# Epoch 80 completed. Saliency maps generated.
# Epoch 81/100
# -------------------------------
# Training Loss = 0.426247, Accuracy = 90.68%
# Validation Loss = 0.824134, Accuracy = 80.38%
# Epoch 81 completed. Saliency maps generated.
# Epoch 82/100
# -------------------------------
# Training Loss = 0.418202, Accuracy = 90.83%
# Validation Loss = 0.841402, Accuracy = 80.11%
# Epoch 82 completed. Saliency maps generated.
# Epoch 83/100
# -------------------------------
# Training Loss = 0.410986, Accuracy = 91.96%
# Validation Loss = 0.822041, Accuracy = 80.38%
# Epoch 83 completed. Saliency maps generated.
# Epoch 84/100
# -------------------------------
# Training Loss = 0.419762, Accuracy = 91.50%
# Validation Loss = 0.821620, Accuracy = 79.84%
# Epoch 84 completed. Saliency maps generated.
# Epoch 85/100
# -------------------------------
# Training Loss = 0.413583, Accuracy = 91.99%
# Validation Loss = 0.840923, Accuracy = 79.84%
# Epoch 85 completed. Saliency maps generated.
# Epoch 86/100
# -------------------------------
# Training Loss = 0.422241, Accuracy = 91.53%
# Validation Loss = 0.825292, Accuracy = 80.38%
# Epoch 86 completed. Saliency maps generated.
# Epoch 87/100
# -------------------------------
# Training Loss = 0.409570, Accuracy = 91.84%
# Validation Loss = 0.827681, Accuracy = 80.11%
# Epoch 87 completed. Saliency maps generated.
# Epoch 88/100
# -------------------------------
# Training Loss = 0.416235, Accuracy = 91.84%
# Validation Loss = 0.850552, Accuracy = 79.84%
# Epoch 88 completed. Saliency maps generated.
# Epoch 89/100
# -------------------------------
# Training Loss = 0.403186, Accuracy = 91.75%
# Validation Loss = 0.853126, Accuracy = 78.20%
# Epoch 89 completed. Saliency maps generated.
# Epoch 90/100
# -------------------------------
# Training Loss = 0.406384, Accuracy = 91.96%
# Validation Loss = 0.829025, Accuracy = 80.38%
# Epoch 90 completed. Saliency maps generated.
# Epoch 91/100
# -------------------------------
# Training Loss = 0.417492, Accuracy = 91.14%
# Validation Loss = 0.825573, Accuracy = 80.38%
# Epoch 91 completed. Saliency maps generated.
# Epoch 92/100
# -------------------------------
# Training Loss = 0.415991, Accuracy = 91.56%
# Validation Loss = 0.822691, Accuracy = 79.02%
# Epoch 92 completed. Saliency maps generated.
# Epoch 93/100
# -------------------------------
# Training Loss = 0.403014, Accuracy = 92.50%
# Validation Loss = 0.832926, Accuracy = 80.11%
# Epoch 93 completed. Saliency maps generated.
# Epoch 94/100
# -------------------------------
# Training Loss = 0.406418, Accuracy = 92.32%
# Validation Loss = 0.843654, Accuracy = 79.02%
# Epoch 94 completed. Saliency maps generated.
# Epoch 95/100
# -------------------------------
# Training Loss = 0.416292, Accuracy = 91.14%
# Validation Loss = 0.842447, Accuracy = 79.02%
# Epoch 95 completed. Saliency maps generated.
# Epoch 96/100
# -------------------------------
# Training Loss = 0.419082, Accuracy = 91.53%
# Validation Loss = 0.842945, Accuracy = 79.56%
# Epoch 96 completed. Saliency maps generated.
# Epoch 97/100
# -------------------------------
# Training Loss = 0.417572, Accuracy = 91.59%
# Validation Loss = 0.824159, Accuracy = 80.93%
# Epoch 97 completed. Saliency maps generated.
# Epoch 98/100
# -------------------------------
# Training Loss = 0.413215, Accuracy = 91.53%
# Validation Loss = 0.836466, Accuracy = 79.29%
# Epoch 98 completed. Saliency maps generated.
# Epoch 99/100
# -------------------------------
# Training Loss = 0.418348, Accuracy = 91.53%
# Validation Loss = 0.845561, Accuracy = 79.02%
# Epoch 99 completed. Saliency maps generated.
# Epoch 100/100
# -------------------------------
# Training Loss = 0.411177, Accuracy = 91.62%
# Validation Loss = 0.830372, Accuracy = 80.38%
# Epoch 100 completed. Saliency maps generated.

# %%
#Plot the graph of train_losses & valid_losses against num_epochs.
epochs = range(1, num_epochs+1)  # Adjusted to match the epoch numbering
plt.plot(epochs, train_losses, 'g', label='Training loss')
plt.plot(epochs, valid_losses, 'b', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
#Plot the graph of train_accuracies & valid_accuracies against num_epochs.
epochs = range(1, num_epochs+1)  # Adjusted to match the epoch numbering
plt.plot(epochs, train_accuracies, 'g', label='Training Accuracy')
plt.plot(epochs, valid_accuracies, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
test_set = dataset(test_df,f'{path}test_images',image_transform = image_transform,train = False )

test_dataloader = DataLoader(test_set, batch_size=32, shuffle=False) #DataLoader for test_set.

# %%
def test(dataloader,model):
    '''
    test function predicts the labels given an image batches.
    
    Args :
         dataloader: DataLoader for the test_set.
         model: Given an input produces an output by multiplying the input with the model weights.
         
    Returns :
         List of predicted labels.
    '''
    
    model.eval() #Sets the model for evaluation.
    
    labels = [] #List to store the predicted labels.
    
    with torch.no_grad():
        
        for batch,x in enumerate(dataloader):
            
            output = model(x.to(device))
            
            predictions = output.argmax(dim=1).cpu().detach().tolist() #Predicted labels for an image batch.
            labels.extend(predictions)
                
    print('Testing has completed')
            
    return labels

# %%
labels = test(test_dataloader,model) #Calls the test function.

# %%
print(labels)
