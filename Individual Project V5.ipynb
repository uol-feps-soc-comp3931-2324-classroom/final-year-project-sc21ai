# %%
import pandas as pd #For reading csv files.
import numpy as np 
import matplotlib.pyplot as plt #For plotting.
import matplotlib.colors as mcolors

import PIL.Image as Image #For working with image files.

#Importing torch
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset,DataLoader #For working with data.

from torchvision import models,transforms #For pretrained models,image transformations.

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

import time
import os

torch.cuda.empty_cache()

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu') #Use GPU if it's available or else use CPU.
print(device) #Prints the device we're using.
# Out:
# cuda

# %%
path = "aptos2019-blindness-detection/"

train_df = pd.read_csv(f"{path}train.csv")
print(f'No.of.training_samples: {len(train_df)}')

test_df = pd.read_csv(f'{path}test.csv')
print(f'No.of.testing_samples: {len(test_df)}')
# Out:
# No.of.training_samples: 3662
# No.of.testing_samples: 1928

# %% [raw]
# def check_image_load(image_path):
#     try:
#         # Attempt to open the image
#         Image.open(image_path).convert('RGB')
#         return True  # Image successfully loaded
#     except:
#         return False  # Image failed to load
#
# # For train_df
# train_df['image_loaded'] = train_df['id_code'].apply(lambda x: check_image_load(f"{path}train_images/{x}.png"))
#
# # Filter out images that failed to load
# train_df_filtered = train_df[train_df['image_loaded']]
#
# print(f'No.of.training_samples after excluding failed images: {len(train_df_filtered)}')
#
# # For test_df
# test_df['image_loaded'] = test_df['id_code'].apply(lambda x: check_image_load(f"{path}test_images/{x}.png"))
#
# # Filter out images that failed to load
# test_df_filtered = test_df[test_df['image_loaded']]
#
# print(f'No.of.testing_samples after excluding failed images: {len(test_df_filtered)}')

# %%
bins = np.arange(-0.5, max(train_df.diagnosis) + 1.5, 1)

# Plot histogram with adjusted bins
plt.hist(train_df.diagnosis, bins=bins, rwidth=0.8, align='mid')

# Set x-ticks to be at the center of each bar
plt.xticks(np.arange(0, 5, 1))

# Turn off the grid or adjust it
plt.grid(False)

# Show the plot
plt.show()

# %%
#As you can see,the data is imbalanced.
#So we've to calculate weights for each class,which can be used in calculating loss.

from sklearn.utils import class_weight #For calculating weights for each class.
class_weights = class_weight.compute_class_weight(class_weight='balanced',classes=np.array([0,1,2,3,4]),y=train_df['diagnosis'].values)
class_weights = torch.tensor(class_weights,dtype=torch.float).to(device)
 
print(class_weights) #Prints the calculated weights for the classes.
# Out:
# tensor([0.4058, 1.9795, 0.7331, 3.7948, 2.4827], device='cuda:0')

# %%
# Set the number of images to display
num_images = 20

# Generate a list of random indices based on the DataFrame length
random_indices = np.random.randint(0, len(train_df), size=num_images)

# Set up the plot - adjust subplot grid as needed
fig, axes = plt.subplots(nrows=4, ncols=5, figsize=(20, 16)) # Adjust nrows and ncols based on num_images
axes = axes.flatten()

for i, ax in zip(random_indices, axes):
    # Construct the full path to the image
    sample_image_path = f'{path}train_images/{train_df["id_code"][i]}.png'
    sample_image = Image.open(sample_image_path)
    
    # Plotting
    ax.imshow(sample_image)
    ax.axis('off') # Hides the axis
    ax.set_title(f'Class: {train_df["diagnosis"][i]}') # Shows the class of each image

# Adjusts subplot params so that the subplot(s) fits in to the figure area
plt.tight_layout()
plt.show()

# %%
class BackgroundRemoval:
    def __call__(self, img):
        # Convert image to grayscale for thresholding
        gray = img.convert('L')
        img_array = np.array(gray)

        # Create a binary mask where non-black pixels are set to 255 (non-transparent)
        threshold = 10
        mask = np.where(img_array > threshold, 255, 0).astype(np.uint8)

        # Convert the numpy array mask to a PIL Image
        mask_image = Image.fromarray(mask, mode='L')

        # Apply this mask to the original image to make the background transparent
        img.putalpha(mask_image)

        return img

# %%
class dataset(Dataset): # Inherits from the Dataset class.
    '''
    dataset class overloads the __init__, __len__, __getitem__ methods of the Dataset class. 
    
    Attributes :
        df:  DataFrame object for the csv file.
        data_path: Location of the dataset.
        image_transform: Transformations to apply to the image.
        train: A boolean indicating whether it is a training_set or not.
    '''
    
    def __init__(self,df,data_path,image_transform=None,train=True): # Constructor.
        super(Dataset,self).__init__() #Calls the constructor of the Dataset class.
        self.df = df
        self.data_path = data_path
        self.image_transform = image_transform
        self.train = train
        
    def __len__(self):
        return len(self.df) #Returns the number of samples in the dataset.
    
    def __getitem__(self,index):
        image_id = self.df['id_code'][index]
        image = Image.open(f'{self.data_path}/{image_id}.png') #Image.
        if self.image_transform :
            image = self.image_transform(image) #Applies transformation to the image.
        
        if self.train :
            label = self.df['diagnosis'][index] #Label.
            return image,label #If train == True, return image & label.
        
        else:
            return image #If train != True, return image.

# %%
class DoubleConv(nn.Module):
    """(convolution => [BN] => ReLU) * 2"""
    def __init__(self, in_channels, out_channels, mid_channels=None):
        super().__init__()
        if not mid_channels:
            mid_channels = out_channels
        self.double_conv = nn.Sequential(
            nn.Conv2d(in_channels, mid_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(mid_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(mid_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        return self.double_conv(x)

# %%
class ConvBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(ConvBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1)
        self.relu = nn.ReLU(inplace=True)
        self.dropout = nn.Dropout2d(0.5)  # Spatial dropout
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1)

    def forward(self, x):
        x = self.conv1(x)
        x = self.relu(x)
        x = self.conv2(x)
        x = self.relu(x)
        return x

# %%
class AttentionGate(nn.Module):
    def __init__(self, F_g, F_l, F_int):
        super(AttentionGate, self).__init__()
        self.W_g = nn.Sequential(
            nn.Conv2d(F_g, F_int, kernel_size=1, stride=1, padding=0, bias=True),
            nn.BatchNorm2d(F_int)
        )
        
        self.W_x = nn.Sequential(
            nn.Conv2d(F_l, F_int, kernel_size=1, stride=1, padding=0, bias=True),
            nn.BatchNorm2d(F_int)
        )

        self.psi = nn.Sequential(
            nn.Conv2d(F_int, 1, kernel_size=1, stride=1, padding=0, bias=True),
            nn.BatchNorm2d(1),
            nn.Sigmoid()
        )
        
        self.relu = nn.ReLU(inplace=True)

    def forward(self, g, x):
        g1 = self.W_g(g)
        x1 = self.W_x(x)
        psi = self.relu(g1 + x1)
        psi = self.psi(psi)
        return x * psi

# %%
class UpConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(UpConv, self).__init__()
        self.up = nn.Sequential(
            nn.Upsample(scale_factor=2),
            nn.Conv2d(in_channels, out_channels, kernel_size=1)
        )

    def forward(self, x):
        return self.up(x)

# %%
class AttentionUNet(nn.Module):
    def __init__(self, in_channels=4, out_channels=5):
        super(AttentionUNet, self).__init__()
        # Reducing the number of filters in each convolutional block
        self.inc = DoubleConv(in_channels, 32)  # Reduced from 64 to 32
        self.down1 = DoubleConv(32, 64)  # Reduced from 128 to 64
        self.down2 = DoubleConv(64, 128)  # Reduced from 256 to 128
        self.down3 = DoubleConv(128, 256)  # Reduced from 512 to 256

        self.up1 = UpConv(256, 128)
        self.att1 = AttentionGate(128, 128, 64)  # Simplified attention gate
        self.up_conv1 = DoubleConv(256, 128)

        self.up2 = UpConv(128, 64)
        self.att2 = AttentionGate(64, 64, 32)
        self.up_conv2 = DoubleConv(128, 64)

        self.up3 = UpConv(64, 32)
        self.att3 = AttentionGate(32, 32, 16)
        self.up_conv3 = DoubleConv(64, 32)

        self.outc = nn.Conv2d(32, out_channels, kernel_size=1)
        
        self.global_avg_pool = nn.AdaptiveAvgPool2d((1, 1))
        self.classifier = nn.Linear(32, out_channels)  # Reduced width

    def forward(self, x):
        x1 = self.inc(x)
        x2 = F.max_pool2d(self.down1(x1), 2)
        x3 = F.max_pool2d(self.down2(x2), 2)
        x4 = F.max_pool2d(self.down3(x3), 2)

        x = self.up1(x4)
        g1 = self.att1(x, x3)
        x = self.up_conv1(torch.cat([x, g1], dim=1))

        x = self.up2(x)
        g2 = self.att2(x, x2)
        x = self.up_conv2(torch.cat([x, g2], dim=1))

        x = self.up3(x)
        g3 = self.att3(x, x1)
        x = self.up_conv3(torch.cat([x, g3], dim=1))

        x = self.global_avg_pool(x)
        x = x.view(x.size(0), -1)
        logits = self.classifier(x)
        return logits

# %%
class EarlyStopping:
    """Early stops the training if validation loss doesn't improve after a given patience."""
    def __init__(self, patience=7, verbose=False, delta=0):
        """
        Args:
            patience (int): How long to wait after last time validation loss improved.
                            Default: 7
            verbose (bool): If True, prints a message for each validation loss improvement. 
                            Default: False
            delta (float): Minimum change in the monitored quantity to qualify as an improvement.
                            Default: 0
        """
        self.patience = patience
        self.verbose = verbose
        self.delta = delta
        self.best_score = None
        self.early_stop = False
        self.counter = 0

    def __call__(self, val_loss, model):
        score = -val_loss

        if self.best_score is None:
            self.best_score = score
        elif score < self.best_score + self.delta:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.counter = 0

# %%
image_transform = transforms.Compose([BackgroundRemoval(),
                                      transforms.Resize([256, 256]),
                                      transforms.ToTensor(),
                                      transforms.Normalize((0.485, 0.456, 0.406, 0), (0.229, 0.224, 0.225, 1))]) #Transformations to apply to the image.
data_set = dataset(train_df,f'{path}train_images',image_transform=image_transform)

#Split the data_set so that valid_set contains 0.1 samples of the data_set. 
train_size = int(0.9 * len(data_set))
valid_size = len(data_set) - train_size

train_set, valid_set = torch.utils.data.random_split(data_set, [train_size, valid_size])

# %%
train_dataloader = DataLoader(train_set,batch_size=16,shuffle=True, num_workers=4) #DataLoader for train_set.
valid_dataloader = DataLoader(valid_set,batch_size=16,shuffle=False, num_workers=4) #DataLoader for validation_set.

# %%
def calculate_metrics(y_true, y_pred):
    accuracy = accuracy_score(y_true, y_pred)*100
    precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
    recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
    f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)
    return accuracy, precision, recall, f1

# %%
def evaluate_model(dataloader, model, criterion):
    model.eval()
    y_true = []
    y_pred = []
    running_loss = 0.0
    
    with torch.no_grad():
        for inputs, labels in dataloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            running_loss += loss.item() * inputs.size(0)
            _, preds = torch.max(outputs, 1)
            y_true.extend(labels.cpu().numpy())
            y_pred.extend(preds.cpu().numpy())
    
    epoch_loss = running_loss / len(dataloader.dataset)
    metrics = calculate_metrics(y_true, y_pred)
    return epoch_loss, metrics[0], metrics[1], metrics[2], metrics[3]

# %%
model = AttentionUNet() 
model = model.to(device) #Moves the model to the device.

# %%
def generate_saliency_maps(model, dataloader, epoch, device, save_dir, num_images=enumerate(valid_dataloader)):
    model.eval()
    epoch_dir = os.path.join(save_dir, f'Epoch_{epoch+1}')
    os.makedirs(epoch_dir, exist_ok=True)

    total_images_processed = 0
    images_processed = 0

    # Create a custom thermal-like colormap from blue to red
    colors = [(0, 0, 1, 1)] + [(x, 0, 1-x, 1) for x in np.linspace(0, 1, 128)] + [(1, x, 0, 1) for x in np.linspace(0, 1, 127)]
    cmap = mcolors.LinearSegmentedColormap.from_list('custom_thermal', colors, N=256)

    # Iterate over all batches
    for batch_idx, (images, labels) in enumerate(dataloader):
        images = images.to(device)

        for idx in range(images.size(0)):
            if images_processed < num_images:
                image = images[idx].unsqueeze(0)
                image.requires_grad = True

                # Forward pass
                outputs = model(image)
                score, predicted = torch.max(outputs, 1)

                # Backward pass
                model.zero_grad()
                score.backward()

                # Saliency map computation
                saliency = image.grad.data.abs().squeeze()
                saliency = saliency.sum(dim=0)  # Sum across the color channels to get a 2D saliency map
                saliency = saliency / saliency.max()  # Normalize

                # Normalize the original image for display
                original_img = image.cpu().detach().numpy().squeeze().transpose(1, 2, 0)
                original_img = (original_img - original_img.min()) / (original_img.max() - original_img.min())

                # Plotting
                fig, ax = plt.subplots(1, 2, figsize=(12, 6))
                # Original image
                ax[0].imshow(original_img)
                ax[0].set_title('Original Image')
                ax[0].axis('off')

                # Saliency map
                ax[1].imshow(saliency.cpu(), cmap=cmap)
                ax[1].set_title('Saliency Map')
                ax[1].axis('off')

                plt.suptitle(f'Actual: {labels[idx].item()}, Predicted: {predicted.item()}')
                plt.savefig(os.path.join(epoch_dir, f'Saliency_{total_images_processed}.png'))
                plt.close()

                images_processed += 1
            total_images_processed += 1

            if images_processed >= num_images:
                break
        if images_processed >= num_images:
            break

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-5)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=5, verbose=True)
early_stopping = EarlyStopping(patience=10, verbose=True)

# Compute class weights and convert to tensor
class_weights = torch.tensor(class_weight.compute_class_weight(class_weight='balanced', classes=np.unique(train_df['diagnosis']), y=train_df['diagnosis'].values), dtype=torch.float).to(device)
criterion = nn.CrossEntropyLoss(weight=class_weights)

num_epochs = 45

# Initialize lists to store metrics for plotting later
train_losses, valid_losses = [], []
train_accuracies, valid_accuracies = [], []
train_precision, valid_precision = [], []
train_recall, valid_recall = [], []
train_f1, valid_f1 = [], []

total_time = 0  # Initialize total time taken

for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    train_correct = 0
    train_total = 0
    start_time = time.time()  # Start time of the epoch

    # Lists to collect true and predicted labels for this epoch
    train_true_labels = []
    train_predicted_labels = []

    for images, labels in train_dataloader:
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        
        _, predicted = torch.max(outputs.data, 1)
        train_total += labels.size(0)
        train_correct += (predicted == labels).sum().item()

        # Collect labels and predictions
        train_true_labels.extend(labels.cpu().numpy())
        train_predicted_labels.extend(predicted.cpu().numpy())

    epoch_duration = time.time() - start_time  # Calculate duration of epoch
    total_time += epoch_duration  # Update the total time taken
    
    # Compute and store training metrics
    training_loss = running_loss / len(train_dataloader)
    training_accuracy = 100 * train_correct / train_total
    train_losses.append(training_loss)
    train_accuracies.append(training_accuracy)
    
    # Compute and store additional training metrics (precision, recall, F1)
    train_metrics = calculate_metrics(train_true_labels, train_predicted_labels)
    train_precision.append(train_metrics[1])
    train_recall.append(train_metrics[2])
    train_f1.append(train_metrics[3])

    # Validation phase
    model.eval()
    valid_metrics = evaluate_model(valid_dataloader, model, criterion)
    
    # Extract and store validation metrics
    validation_loss, validation_accuracy, validation_precision, validation_recall, validation_f1 = valid_metrics
    valid_losses.append(validation_loss)
    valid_accuracies.append(validation_accuracy)
    valid_precision.append(validation_precision)
    valid_recall.append(validation_recall)
    valid_f1.append(validation_f1)
    
    scheduler.step(validation_loss)
    
    # Print training and validation results
    print(f'Training and Validation Metrics for Epoch {epoch+1}/{num_epochs}')
    print('-------------------------------')
    print(f'Training - Loss: {training_loss:.4f}, Acc: {training_accuracy:.2f}%, Prec: {train_metrics[1]:.4f}, Rec: {train_metrics[2]:.4f}, F1: {train_metrics[3]:.4f}')
    print(f'Validation - Loss: {validation_loss:.4f}, Acc: {validation_accuracy:.2f}%, Prec: {validation_precision:.4f}, Rec: {validation_recall:.4f}, F1: {validation_f1:.4f}')
    print(f'Epoch Duration: {epoch_duration:.2f} seconds, Total Time Elapsed: {total_time:.2f} seconds')
    # Generate saliency maps at the end of each epoch
    generate_saliency_maps(model, valid_dataloader, epoch, device, 'v5_saliency_maps')
    print(f'Epoch {epoch+1} completed. Saliency maps generated.')
    
    if early_stopping(validation_loss, model):
        print("Early stopping triggered.")
        break
        
    torch.cuda.empty_cache()

print(f'Total Training Time: {total_time:.2f} seconds')
# Out:
# Training and Validation Metrics for Epoch 1/45
# -------------------------------
# Training - Loss: 1.5149, Acc: 49.14%, Prec: 0.4853, Rec: 0.4914, F1: 0.4858
# Validation - Loss: 1.6432, Acc: 55.59%, Prec: 0.5184, Rec: 0.5559, F1: 0.4708
# Epoch Duration: 138.10 seconds, Total Time Elapsed: 138.10 seconds
# Epoch 1 completed. Saliency maps generated.
# Training and Validation Metrics for Epoch 2/45
# -------------------------------
# Training - Loss: 1.4010, Acc: 50.44%, Prec: 0.5747, Rec: 0.5044, F1: 0.4993
# Validation - Loss: 1.4835, Acc: 62.40%, Prec: 0.7536, Rec: 0.6240, F1: 0.6103
# Epoch Duration: 144.30 seconds, Total Time Elapsed: 282.40 seconds
# Epoch 2 completed. Saliency maps generated.
# Training and Validation Metrics for Epoch 3/45
# -------------------------------
# Training - Loss: 1.3334, Acc: 59.88%, Prec: 0.6168, Rec: 0.5988, F1: 0.6020
# Validation - Loss: 1.2758, Acc: 65.67%, Prec: 0.7268, Rec: 0.6567, F1: 0.6619
# Epoch Duration: 138.43 seconds, Total Time Elapsed: 420.83 seconds
# Epoch 3 completed. Saliency maps generated.
# Training and Validation Metrics for Epoch 4/45
# -------------------------------
# Training - Loss: 1.2823, Acc: 61.24%, Prec: 0.6292, Rec: 0.6124, F1: 0.6157
# Validation - Loss: 1.2614, Acc: 62.13%, Prec: 0.6663, Rec: 0.6213, F1: 0.6170
# Epoch Duration: 144.62 seconds, Total Time Elapsed: 565.45 seconds
# Epoch 4 completed. Saliency maps generated.
# Training and Validation Metrics for Epoch 5/45
# -------------------------------
# Training - Loss: 1.2436, Acc: 66.22%, Prec: 0.6482, Rec: 0.6622, F1: 0.6530
# Validation - Loss: 1.2257, Acc: 65.67%, Prec: 0.6782, Rec: 0.6567, F1: 0.6615
# Epoch Duration: 140.93 seconds, Total Time Elapsed: 706.39 seconds
# Epoch 5 completed. Saliency maps generated.
# Training and Validation Metrics for Epoch 6/45
# -------------------------------
# Training - Loss: 1.2351, Acc: 63.82%, Prec: 0.6522, Rec: 0.6382, F1: 0.6428
# Validation - Loss: 1.3423, Acc: 55.31%, Prec: 0.6493, Rec: 0.5531, F1: 0.5740
# Epoch Duration: 140.38 seconds, Total Time Elapsed: 846.77 seconds
# Epoch 6 completed. Saliency maps generated.
# Training and Validation Metrics for Epoch 7/45
# -------------------------------
# Training - Loss: 1.2239, Acc: 65.43%, Prec: 0.6606, Rec: 0.6543, F1: 0.6556
# Validation - Loss: 1.1909, Acc: 67.57%, Prec: 0.6886, Rec: 0.6757, F1: 0.6767
# Epoch Duration: 139.89 seconds, Total Time Elapsed: 986.65 seconds
# Epoch 7 completed. Saliency maps generated.
# Training and Validation Metrics for Epoch 8/45
# -------------------------------
# Training - Loss: 1.2092, Acc: 64.52%, Prec: 0.6683, Rec: 0.6452, F1: 0.6497
# Validation - Loss: 1.3335, Acc: 61.85%, Prec: 0.6873, Rec: 0.6185, F1: 0.5749
# Epoch Duration: 140.62 seconds, Total Time Elapsed: 1127.28 seconds
# Epoch 8 completed. Saliency maps generated.
# Training and Validation Metrics for Epoch 9/45
# -------------------------------
# Training - Loss: 1.2130, Acc: 65.22%, Prec: 0.6704, Rec: 0.6522, F1: 0.6555
# Validation - Loss: 1.2033, Acc: 71.12%, Prec: 0.7312, Rec: 0.7112, F1: 0.7110
# Epoch Duration: 145.61 seconds, Total Time Elapsed: 1272.88 seconds
# Epoch 9 completed. Saliency maps generated.
# Training and Validation Metrics for Epoch 10/45
# -------------------------------
# Training - Loss: 1.1964, Acc: 65.89%, Prec: 0.6785, Rec: 0.6589, F1: 0.6602
# Validation - Loss: 1.2111, Acc: 67.30%, Prec: 0.7056, Rec: 0.6730, F1: 0.6699
# Epoch Duration: 141.47 seconds, Total Time Elapsed: 1414.35 seconds
# Epoch 10 completed. Saliency maps generated.
# Training and Validation Metrics for Epoch 11/45
# -------------------------------
# Training - Loss: 1.1984, Acc: 65.43%, Prec: 0.6733, Rec: 0.6543, F1: 0.6576
# Validation - Loss: 1.2350, Acc: 64.31%, Prec: 0.7010, Rec: 0.6431, F1: 0.6629
# Epoch Duration: 143.37 seconds, Total Time Elapsed: 1557.73 seconds
# Epoch 11 completed. Saliency maps generated.
# Training and Validation Metrics for Epoch 12/45
# -------------------------------
# Training - Loss: 1.1974, Acc: 66.68%, Prec: 0.6872, Rec: 0.6668, F1: 0.6703
# Validation - Loss: 1.1959, Acc: 71.12%, Prec: 0.7115, Rec: 0.7112, F1: 0.7009
# Epoch Duration: 142.79 seconds, Total Time Elapsed: 1700.52 seconds
# Epoch 12 completed. Saliency maps generated.
# Epoch 00013: reducing learning rate of group 0 to 1.0000e-04.
# Training and Validation Metrics for Epoch 13/45
# -------------------------------
# Training - Loss: 1.1865, Acc: 65.46%, Prec: 0.6916, Rec: 0.6546, F1: 0.6602
# Validation - Loss: 1.3757, Acc: 52.59%, Prec: 0.6884, Rec: 0.5259, F1: 0.5735
# Epoch Duration: 140.03 seconds, Total Time Elapsed: 1840.54 seconds
# Epoch 13 completed. Saliency maps generated.
# Training and Validation Metrics for Epoch 14/45
# -------------------------------
# Training - Loss: 1.1609, Acc: 66.10%, Prec: 0.6869, Rec: 0.6610, F1: 0.6646
# Validation - Loss: 1.1716, Acc: 71.66%, Prec: 0.7376, Rec: 0.7166, F1: 0.7197
# Epoch Duration: 142.67 seconds, Total Time Elapsed: 1983.21 seconds
# Epoch 14 completed. Saliency maps generated.
# Training and Validation Metrics for Epoch 15/45
# -------------------------------
# Training - Loss: 1.1647, Acc: 67.19%, Prec: 0.6961, Rec: 0.6719, F1: 0.6756
# Validation - Loss: 1.1680, Acc: 71.39%, Prec: 0.7385, Rec: 0.7139, F1: 0.7172
# Epoch Duration: 142.39 seconds, Total Time Elapsed: 2125.60 seconds
# Epoch 15 completed. Saliency maps generated.
# Training and Validation Metrics for Epoch 16/45
# -------------------------------
# Training - Loss: 1.1549, Acc: 67.62%, Prec: 0.6997, Rec: 0.6762, F1: 0.6779
# Validation - Loss: 1.1696, Acc: 71.93%, Prec: 0.7437, Rec: 0.7193, F1: 0.7233
# Epoch Duration: 144.70 seconds, Total Time Elapsed: 2270.30 seconds
# Epoch 16 completed. Saliency maps generated.
# Training and Validation Metrics for Epoch 17/45
# -------------------------------
# Training - Loss: 1.1547, Acc: 65.98%, Prec: 0.6907, Rec: 0.6598, F1: 0.6649
# Validation - Loss: 1.1608, Acc: 71.39%, Prec: 0.7462, Rec: 0.7139, F1: 0.7193
# Epoch Duration: 141.44 seconds, Total Time Elapsed: 2411.74 seconds
# Epoch 17 completed. Saliency maps generated.
# Training and Validation Metrics for Epoch 18/45
# -------------------------------
# Training - Loss: 1.1544, Acc: 66.98%, Prec: 0.6966, Rec: 0.6698, F1: 0.6725
# Validation - Loss: 1.1571, Acc: 72.21%, Prec: 0.7411, Rec: 0.7221, F1: 0.7227
# Epoch Duration: 142.87 seconds, Total Time Elapsed: 2554.61 seconds
# Epoch 18 completed. Saliency maps generated.
# Training and Validation Metrics for Epoch 19/45
# -------------------------------
# Training - Loss: 1.1479, Acc: 67.16%, Prec: 0.6947, Rec: 0.6716, F1: 0.6727
# Validation - Loss: 1.1621, Acc: 70.84%, Prec: 0.7328, Rec: 0.7084, F1: 0.7138
# Epoch Duration: 142.32 seconds, Total Time Elapsed: 2696.93 seconds
# Epoch 19 completed. Saliency maps generated.
# Training and Validation Metrics for Epoch 20/45
# -------------------------------
# Training - Loss: 1.1459, Acc: 67.62%, Prec: 0.6959, Rec: 0.6762, F1: 0.6771
# Validation - Loss: 1.1509, Acc: 71.66%, Prec: 0.7444, Rec: 0.7166, F1: 0.7219
# Epoch Duration: 143.21 seconds, Total Time Elapsed: 2840.14 seconds
# Epoch 20 completed. Saliency maps generated.
# Training and Validation Metrics for Epoch 21/45
# -------------------------------
# Training - Loss: 1.1482, Acc: 67.41%, Prec: 0.6964, Rec: 0.6741, F1: 0.6747
# Validation - Loss: 1.1545, Acc: 71.39%, Prec: 0.7394, Rec: 0.7139, F1: 0.7184
# Epoch Duration: 142.78 seconds, Total Time Elapsed: 2982.91 seconds
# Epoch 21 completed. Saliency maps generated.
# Training and Validation Metrics for Epoch 22/45
# -------------------------------
# Training - Loss: 1.1470, Acc: 67.86%, Prec: 0.7015, Rec: 0.6786, F1: 0.6795
# Validation - Loss: 1.1582, Acc: 70.84%, Prec: 0.7367, Rec: 0.7084, F1: 0.7123
# Epoch Duration: 143.48 seconds, Total Time Elapsed: 3126.39 seconds
# Epoch 22 completed. Saliency maps generated.
# Training and Validation Metrics for Epoch 23/45
# -------------------------------
# Training - Loss: 1.1441, Acc: 68.01%, Prec: 0.7061, Rec: 0.6801, F1: 0.6821
# Validation - Loss: 1.1519, Acc: 71.93%, Prec: 0.7424, Rec: 0.7193, F1: 0.7229
# Epoch Duration: 141.45 seconds, Total Time Elapsed: 3267.84 seconds
# Epoch 23 completed. Saliency maps generated.
# Training and Validation Metrics for Epoch 24/45
# -------------------------------
# Training - Loss: 1.1338, Acc: 67.77%, Prec: 0.7023, Rec: 0.6777, F1: 0.6797
# Validation - Loss: 1.1548, Acc: 71.39%, Prec: 0.7311, Rec: 0.7139, F1: 0.7147
# Epoch Duration: 143.38 seconds, Total Time Elapsed: 3411.22 seconds
# Epoch 24 completed. Saliency maps generated.
# Training and Validation Metrics for Epoch 25/45
# -------------------------------
# Training - Loss: 1.1425, Acc: 67.41%, Prec: 0.6964, Rec: 0.6741, F1: 0.6759
# Validation - Loss: 1.1556, Acc: 70.57%, Prec: 0.7251, Rec: 0.7057, F1: 0.7093
# Epoch Duration: 144.63 seconds, Total Time Elapsed: 3555.85 seconds
# Epoch 25 completed. Saliency maps generated.
# Epoch 00026: reducing learning rate of group 0 to 1.0000e-05.
# Training and Validation Metrics for Epoch 26/45
# -------------------------------
# Training - Loss: 1.1409, Acc: 67.53%, Prec: 0.6992, Rec: 0.6753, F1: 0.6774
# Validation - Loss: 1.1552, Acc: 70.03%, Prec: 0.7458, Rec: 0.7003, F1: 0.7110
# Epoch Duration: 145.26 seconds, Total Time Elapsed: 3701.11 seconds
# Epoch 26 completed. Saliency maps generated.
# Training and Validation Metrics for Epoch 27/45
# -------------------------------
# Training - Loss: 1.1305, Acc: 68.04%, Prec: 0.7067, Rec: 0.6804, F1: 0.6830
# Validation - Loss: 1.1509, Acc: 71.12%, Prec: 0.7386, Rec: 0.7112, F1: 0.7154
# Epoch Duration: 143.08 seconds, Total Time Elapsed: 3844.20 seconds
# Epoch 27 completed. Saliency maps generated.
# Training and Validation Metrics for Epoch 28/45
# -------------------------------
# Training - Loss: 1.1315, Acc: 67.92%, Prec: 0.7017, Rec: 0.6792, F1: 0.6805
# Validation - Loss: 1.1541, Acc: 71.66%, Prec: 0.7389, Rec: 0.7166, F1: 0.7204
# Epoch Duration: 143.50 seconds, Total Time Elapsed: 3987.70 seconds
# Epoch 28 completed. Saliency maps generated.
# Training and Validation Metrics for Epoch 29/45
# -------------------------------
# Training - Loss: 1.1304, Acc: 67.44%, Prec: 0.7005, Rec: 0.6744, F1: 0.6767
# Validation - Loss: 1.1495, Acc: 71.12%, Prec: 0.7448, Rec: 0.7112, F1: 0.7178
# Epoch Duration: 140.16 seconds, Total Time Elapsed: 4127.86 seconds
# Epoch 29 completed. Saliency maps generated.
# Training and Validation Metrics for Epoch 30/45
# -------------------------------
# Training - Loss: 1.1341, Acc: 67.56%, Prec: 0.6985, Rec: 0.6756, F1: 0.6769
# Validation - Loss: 1.1481, Acc: 72.21%, Prec: 0.7391, Rec: 0.7221, F1: 0.7230
# Epoch Duration: 140.31 seconds, Total Time Elapsed: 4268.17 seconds
# Epoch 30 completed. Saliency maps generated.
# Training and Validation Metrics for Epoch 31/45
# -------------------------------
# Training - Loss: 1.1382, Acc: 67.80%, Prec: 0.7042, Rec: 0.6780, F1: 0.6791
# Validation - Loss: 1.1587, Acc: 71.39%, Prec: 0.7417, Rec: 0.7139, F1: 0.7186
# Epoch Duration: 142.85 seconds, Total Time Elapsed: 4411.02 seconds
# Epoch 31 completed. Saliency maps generated.
# Training and Validation Metrics for Epoch 32/45
# -------------------------------
# Training - Loss: 1.1305, Acc: 67.92%, Prec: 0.7041, Rec: 0.6792, F1: 0.6805
# Validation - Loss: 1.1477, Acc: 72.21%, Prec: 0.7420, Rec: 0.7221, F1: 0.7227
# Epoch Duration: 134.87 seconds, Total Time Elapsed: 4545.89 seconds
# Epoch 32 completed. Saliency maps generated.
# Training and Validation Metrics for Epoch 33/45
# -------------------------------
# Training - Loss: 1.1293, Acc: 67.74%, Prec: 0.7006, Rec: 0.6774, F1: 0.6790
# Validation - Loss: 1.1523, Acc: 71.93%, Prec: 0.7440, Rec: 0.7193, F1: 0.7243
# Epoch Duration: 132.00 seconds, Total Time Elapsed: 4677.88 seconds
# Epoch 33 completed. Saliency maps generated.
# Training and Validation Metrics for Epoch 34/45
# -------------------------------
# Training - Loss: 1.1319, Acc: 67.25%, Prec: 0.7006, Rec: 0.6725, F1: 0.6748
# Validation - Loss: 1.1449, Acc: 72.21%, Prec: 0.7454, Rec: 0.7221, F1: 0.7249
# Epoch Duration: 131.40 seconds, Total Time Elapsed: 4809.28 seconds
# Epoch 34 completed. Saliency maps generated.
# Training and Validation Metrics for Epoch 35/45
# -------------------------------
# Training - Loss: 1.1354, Acc: 67.89%, Prec: 0.7051, Rec: 0.6789, F1: 0.6799
# Validation - Loss: 1.1509, Acc: 71.39%, Prec: 0.7410, Rec: 0.7139, F1: 0.7188
# Epoch Duration: 130.66 seconds, Total Time Elapsed: 4939.94 seconds
# Epoch 35 completed. Saliency maps generated.
# Training and Validation Metrics for Epoch 36/45
# -------------------------------
# Training - Loss: 1.1232, Acc: 68.07%, Prec: 0.7087, Rec: 0.6807, F1: 0.6828
# Validation - Loss: 1.1474, Acc: 71.39%, Prec: 0.7399, Rec: 0.7139, F1: 0.7187
# Epoch Duration: 131.47 seconds, Total Time Elapsed: 5071.41 seconds
# Epoch 36 completed. Saliency maps generated.
# Training and Validation Metrics for Epoch 37/45
# -------------------------------
# Training - Loss: 1.1275, Acc: 67.53%, Prec: 0.6979, Rec: 0.6753, F1: 0.6759
# Validation - Loss: 1.1452, Acc: 71.66%, Prec: 0.7376, Rec: 0.7166, F1: 0.7202
# Epoch Duration: 130.78 seconds, Total Time Elapsed: 5202.19 seconds
# Epoch 37 completed. Saliency maps generated.
# Training and Validation Metrics for Epoch 38/45
# -------------------------------
# Training - Loss: 1.1310, Acc: 67.50%, Prec: 0.7028, Rec: 0.6750, F1: 0.6773
# Validation - Loss: 1.1432, Acc: 72.21%, Prec: 0.7456, Rec: 0.7221, F1: 0.7253
# Epoch Duration: 131.82 seconds, Total Time Elapsed: 5334.01 seconds
# Epoch 38 completed. Saliency maps generated.
# Training and Validation Metrics for Epoch 39/45
# -------------------------------
# Training - Loss: 1.1310, Acc: 68.01%, Prec: 0.7048, Rec: 0.6801, F1: 0.6815
# Validation - Loss: 1.1456, Acc: 71.12%, Prec: 0.7346, Rec: 0.7112, F1: 0.7139
# Epoch Duration: 131.91 seconds, Total Time Elapsed: 5465.92 seconds
# Epoch 39 completed. Saliency maps generated.
# Training and Validation Metrics for Epoch 40/45
# -------------------------------
# Training - Loss: 1.1266, Acc: 68.13%, Prec: 0.7060, Rec: 0.6813, F1: 0.6827
# Validation - Loss: 1.1438, Acc: 72.48%, Prec: 0.7444, Rec: 0.7248, F1: 0.7271
# Epoch Duration: 131.06 seconds, Total Time Elapsed: 5596.98 seconds
# Epoch 40 completed. Saliency maps generated.
# Training and Validation Metrics for Epoch 41/45
# -------------------------------
# Training - Loss: 1.1184, Acc: 68.38%, Prec: 0.7104, Rec: 0.6838, F1: 0.6857
# Validation - Loss: 1.1448, Acc: 72.21%, Prec: 0.7446, Rec: 0.7221, F1: 0.7246
# Epoch Duration: 131.26 seconds, Total Time Elapsed: 5728.24 seconds
# Epoch 41 completed. Saliency maps generated.
# Training and Validation Metrics for Epoch 42/45
# -------------------------------
# Training - Loss: 1.1287, Acc: 67.95%, Prec: 0.7049, Rec: 0.6795, F1: 0.6799
# Validation - Loss: 1.1449, Acc: 71.39%, Prec: 0.7425, Rec: 0.7139, F1: 0.7189
# Epoch Duration: 131.88 seconds, Total Time Elapsed: 5860.13 seconds
# Epoch 42 completed. Saliency maps generated.
# Training and Validation Metrics for Epoch 43/45
# -------------------------------
# Training - Loss: 1.1286, Acc: 68.29%, Prec: 0.7102, Rec: 0.6829, F1: 0.6851
# Validation - Loss: 1.1434, Acc: 71.66%, Prec: 0.7411, Rec: 0.7166, F1: 0.7198
# Epoch Duration: 130.77 seconds, Total Time Elapsed: 5990.90 seconds
# Epoch 43 completed. Saliency maps generated.
# Training and Validation Metrics for Epoch 44/45
# -------------------------------
# Training - Loss: 1.1193, Acc: 68.19%, Prec: 0.7067, Rec: 0.6819, F1: 0.6832
# Validation - Loss: 1.1430, Acc: 72.21%, Prec: 0.7436, Rec: 0.7221, F1: 0.7251
# Epoch Duration: 131.48 seconds, Total Time Elapsed: 6122.38 seconds
# Epoch 44 completed. Saliency maps generated.
# Training and Validation Metrics for Epoch 45/45
# -------------------------------
# Training - Loss: 1.1200, Acc: 67.98%, Prec: 0.7050, Rec: 0.6798, F1: 0.6819
# Validation - Loss: 1.1527, Acc: 70.03%, Prec: 0.7297, Rec: 0.7003, F1: 0.7069
# Epoch Duration: 131.87 seconds, Total Time Elapsed: 6254.25 seconds
# Epoch 45 completed. Saliency maps generated.
# Total Training Time: 6254.25 seconds

# %%
# After training, plot graphs for all metrics
def plot_metrics(train_metrics, valid_metrics, metric_name):
    epochs = range(1, num_epochs + 1)
    plt.plot(epochs, train_metrics, 'g', label=f'Training {metric_name}')
    plt.plot(epochs, valid_metrics, 'b', label=f'Validation {metric_name}')
    plt.title(f'Training and Validation {metric_name}')
    plt.xlabel('Epochs')
    plt.ylabel(metric_name)
    plt.legend()
    plt.show()

plot_metrics(train_losses, valid_losses, 'Loss')
plot_metrics(train_accuracies, valid_accuracies, 'Accuracy')
plot_metrics(train_precision, valid_precision, 'Precision')
plot_metrics(train_recall, valid_recall, 'Recall')
plot_metrics(train_f1, valid_f1, 'F1 Score')
